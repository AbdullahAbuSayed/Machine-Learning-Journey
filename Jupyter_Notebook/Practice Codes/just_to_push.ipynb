# %%
def evaluate_priority(exam_tomorrow, streak_active):
    if exam_tomorrow and streak_active:
        return "Push minimal code to keep the streak alive, then go study."
    return "Focus on dev work."

action = evaluate_priority(exam_tomorrow=True, streak_active=True)
print(action)
# Out:
# Push minimal code to keep the streak alive, then go study.
