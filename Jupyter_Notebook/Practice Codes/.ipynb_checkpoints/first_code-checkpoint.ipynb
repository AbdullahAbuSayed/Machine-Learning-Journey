# %%
print ("Hello world")
print ("This is a demo")
# Out:
# Hello world
# This is a demo

# %%
a= 5
b= 5
c= int(input("Type a number"))
# Out:
# Type a number 4

# %%
sum = a+b+c

# %%
print(sum)
# Out:
# 14
